# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamilbarbosa/Jornalismo-/blob/main/Dados_vacina%C3%A7%C3%A3_Open_DataSUS_EM_%20PERNAMBUCO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
# importando arquivo csv do Open DataSUS para o Google Drive 

# !wget -P "/content/drive/MyDrive/Vacina covid" https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-02/uf%3DPE/part-00000-2a9d0e2a-e780-4468-b4f8-7e0a1a01b3de.c000.csv
# Out:
# --2021-05-05 00:10:26--  https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-02/uf%3DPE/part-00000-2a9d0e2a-e780-4468-b4f8-7e0a1a01b3de.c000.csv
# Resolving s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)... 52.95.165.2
# Connecting to s3-sa-east-1.amazonaws.com (s3-sa-east-1.amazonaws.com)|52.95.165.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1011395962 (965M) [text/csv]
# Saving to: ‘/content/drive/MyDrive/Vacina covid/part-00000-2a9d0e2a-e780-4468-b4f8-7e0a1a01b3de.c000.csv.2’
#
# part-00000-2a9d0e2a 100%[===================>] 964.54M  18.8MB/s    in 47s
#
# 2021-05-05 00:11:14 (20.6 MB/s) - ‘/content/drive/MyDrive/Vacina covid/part-00000-2a9d0e2a-e780-4468-b4f8-7e0a1a01b3de.c000.csv.2’ saved [1011395962/1011395962]

# %%
# Importando a bibloteca Pandas 

import pandas as pd

# %%
# Criando Data frame 
dados=pd.read_csv("/content/drive/MyDrive/Vacina covid/part-00000-2a9d0e2a-e780-4468-b4f8-7e0a1a01b3de.c000.csv",sep=';')

# %%
dados.estabelecimento_municipio_nome.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                      IGARASSU
# 1                     GARANHUNS
# 2                       AMARAJI
# 3                        RECIFE
# 4                     GARANHUNS
#                    ...
# 1835675                  MANARI
# 1835676         GLORIA DO GOITA
# 1835677    SAO JOSE DO BELMONTE
# 1835678               CAPOEIRAS
# 1835679                PALMARES
# Name: estabelecimento_municipio_nome, Length: 1835680, dtype: object>

# %%
## Quantidade de pessoas vacinadas = 1,835,680 pessoas em pernambuco 

dados.shape
# Out:
# (1835680, 34)

# %%
### Numero de cidades com vacinação em PE - 

## OBS: Todas as cidades-- A unidade federativas PE tem 185 cidades

len(dados["estabelecimento_municipio_nome"].unique())
# Out:
# 185

# %%
# Nomes das cidades com vacinação em PE
dados["estabelecimento_municipio_nome"].unique()
# Out:
# array(['IGARASSU', 'GARANHUNS', 'AMARAJI', 'RECIFE',
#        'AFOGADOS DA INGAZEIRA', 'INAJA', 'OURICURI',
#        'BELEM DE SAO FRANCISCO', 'CARUARU', 'JOAO ALFREDO', 'VICENCIA',
#        'TRINDADE', 'BOM CONSELHO', 'CORRENTES', 'CARNAUBEIRA DA PENHA',
#        'OLINDA', 'XEXEU', 'ALAGOINHA', 'ILHA DE ITAMARACA',
#        'JABOATAO DOS GUARARAPES', 'IPOJUCA', 'AGUAS BELAS', 'PETROLINA',
#        'PAUDALHO', 'JATOBA', 'CABO DE SANTO AGOSTINHO', 'TIMBAUBA',
#        'PAULISTA', 'LAJEDO', 'CABROBO', 'DORMENTES', 'NAZARE DA MATA',
#        'IBIMIRIM', 'PESQUEIRA', 'SAIRE', 'SAO LOURENCO DA MATA',
#        'SAO JOSE DO EGITO', 'GRANITO', 'AGRESTINA', 'GRAVATA',
#        'PETROLANDIA', 'BUIQUE', 'AFRANIO', 'CAETES', 'BEZERROS',
#        'TUPANATINGA', 'CAMARAGIBE', 'TACARATU', 'TABIRA', 'ARCOVERDE',
#        'ITAPETIM', 'ARARIPINA', 'BUENOS AIRES', 'SANHARO', 'PALMARES',
#        'BOM JARDIM', 'TAQUARITINGA DO NORTE', 'ALIANCA', 'PASSIRA',
# ...

# %%
## Numero de vacinados por cidades 

dados["estabelecimento_municipio_nome"].value_counts()
# Out:
# RECIFE                     487895
# JABOATAO DOS GUARARAPES     92257
# CARUARU                     68690
# OLINDA                      57749
# PETROLINA                   51832
#                             ...
# PALMEIRINA                   1391
# INGAZEIRA                    1349
# SOLIDAO                      1296
# ITACURUBA                    1276
# FERNANDO DE NORONHA          1268
# Name: estabelecimento_municipio_nome, Length: 185, dtype: int64

# %%
## Dados de raça entre os vacinados 

dados["paciente_racaCor_valor"].value_counts()
# Out:
# SEM INFORMACAO    563526
# PARDA             446964
# AMARELA           390988
# BRANCA            331328
# PRETA              61837
# INDIGENA           41037
# Name: paciente_racaCor_valor, dtype: int64

# %%
#idade dos vacinados 
# 15 anos ----- 3 pessoas
#

dados["paciente_idade"].value_counts().head(50).sort_index().rename_axis('idade    QTD')
# Out:
# idade    QTD
# 25    11766
# 26    11827
# 27    12044
# 28    12127
# 29    12418
# 30    12337
# 31    13466
# 32    13830
# 33    14021
# 34    14414
# 35    14220
# 36    13417
# 37    14324
# 38    15035
# 39    15146
# 40    14389
# 41    13715
# 42    13205
# 43    12549
# 44    12374
# 45    11578
# 46    11388
# 47    10992
# 60    32485
# 61    35408
# 62    41465
# 63    46729
# 64    55651
# 65    72307
# 66    69901
# 67    66344
# 68    65948
# 69    64991
# 70    80995
# 71    77404
# 72    72943
# 73    70330
# 74    61184
# 75    54989
# 76    51403
# 77    47668
# 78    42868
# 79    36307
# 80    34779
# 81    29929
# 82    24713
# 83    22392
# 84    19427
# 85    18640
# 86    14502
# Name: paciente_idade, dtype: int64

# %%
len(dados["paciente_idade"].unique())
# Out:
# 120

# %%
proporcao = dados["paciente_idade"].value_counts(normalize = True).sort_index()
porcentagem = round(proporcao * 100)
porcentagem.sort_values(ascending = False).head(10).rename_axis('idade    %')
# Out:
# idade    %
# 72    4.0
# 71    4.0
# 65    4.0
# 66    4.0
# 67    4.0
# 68    4.0
# 69    4.0
# 73    4.0
# 70    4.0
# 64    3.0
# Name: paciente_idade, dtype: float64

# %%
#idade dos vacinados 

dados["paciente_idade"].value_counts().head(40).plot(grid="true" ,kind='bar',figsize=(10, 8)).set_title("Grafico IDADE X QUANTIDADE");

# %%
dados.query("paciente_idade").sort_index()
# Out:
#                                    document_id  ... id_sistema_origem
# 0    ac8986a7-a04f-4aee-9a90-665879f85d2f-i0b0  ...             16341
# 0    ac8986a7-a04f-4aee-9a90-665879f85d2f-i0b0  ...             16341
# 1    5be60449-818b-4179-9d32-bfe582537967-i0b0  ...             16341
# 1    5be60449-818b-4179-9d32-bfe582537967-i0b0  ...             16341
# 1    5be60449-818b-4179-9d32-bfe582537967-i0b0  ...             16341
# ..                                         ...  ...               ...
# 121  aa70f0cb-cb2a-4ffd-b93b-a2f90ecde990-i0b0  ...             16341
# 121  aa70f0cb-cb2a-4ffd-b93b-a2f90ecde990-i0b0  ...             16341
# 121  aa70f0cb-cb2a-4ffd-b93b-a2f90ecde990-i0b0  ...             16341
# 121  aa70f0cb-cb2a-4ffd-b93b-a2f90ecde990-i0b0  ...             16341
# 121  aa70f0cb-cb2a-4ffd-b93b-a2f90ecde990-i0b0  ...             16341
#
# [1835680 rows x 34 columns]

# %%
##  Grafico de barras (N de pessoas x idade)

dados["paciente_idade"].hist(bins=99)]
# Out:
#   File "<ipython-input-13-bfa2bba84e2a>", line 3
#     dados["paciente_idade"].hist(bins=99)]
#                                          ^
# SyntaxError: invalid syntax

# %%
##  Grafico de barras (N de pessoas x idade) ampliado

dados["paciente_idade"].hist(bins=100,figsize=(10,8)).set_title("N de PESSOAS X IDADE");

# %%
dados["vacina_categoria_nome"].value_counts()
# Out:
# Faixa Etária                                       1300109
# Trabalhadores de Saúde                              400365
# Povos Indígenas                                      46521
# Pessoas de 60 anos ou mais institucionalizadas       41700
# Povos e Comunidades Tradicionais                     32340
# Forças de Segurança e Salvamento                      5789
# Comorbidades                                          4340
# Pessoas com Deficiência                               1392
# Trabalhadores da Educação                              221
# Trabalhadores Portuários                                47
# Funcionário do Sistema de Privação de Liberdade         40
# Trabalhadores Industriais                               23
# Forças Armadas (membros ativos)                         15
# Pessoas em Situação de Rua                               5
# População Privada de Liberdade                           1
# Name: vacina_categoria_nome, dtype: int64

# %%
# categoria da vacinação 

dados["vacina_categoria_nome"].value_counts(normalize="true")
# Out:
# Faixa Etária                                       7.093149e-01
# Trabalhadores de Saúde                             2.184316e-01
# Povos Indígenas                                    2.538098e-02
# Pessoas de 60 anos ou mais institucionalizadas     2.275073e-02
# Povos e Comunidades Tradicionais                   1.764409e-02
# Forças de Segurança e Salvamento                   3.158369e-03
# Comorbidades                                       2.367822e-03
# Pessoas com Deficiência                            7.594489e-04
# Trabalhadores da Educação                          1.205734e-04
# Trabalhadores Portuários                           2.564231e-05
# Funcionário do Sistema de Privação de Liberdade    2.182324e-05
# Trabalhadores Industriais                          1.254837e-05
# Forças Armadas (membros ativos)                    8.183717e-06
# Pessoas em Situação de Rua                         2.727906e-06
# População Privada de Liberdade                     5.455811e-07
# ...

# %%
# categoria da vacinação "grupos prioritarios"

dados["vacina_grupoAtendimento_nome"].value_counts().head(40)
# Out:
# Pessoas de 70 a 74 anos                                                      334514
# Pessoas de 65 a 69 anos                                                      332990
# Pessoas de 75 a 79 anos                                                      234891
# Outros                                                                       232654
# Pessoas de 80 anos ou mais                                                   220645
# Pessoas de 60 a 64 anos                                                      177069
# Povos indígenas em terras indígenas                                           46521
# Técnico de Enfermagem                                                         44599
# Pessoas de 60 nos ou mais Institucionalizadas                                 41700
# Quilombola                                                                    32337
# Enfermeiro(a)                                                                 18250
# ...

# %%
# Planilha com 40 linhas com os dados( para consulta )

dados.head(40)
# Out:
#                                   document_id  ... id_sistema_origem
# 0   ac8986a7-a04f-4aee-9a90-665879f85d2f-i0b0  ...             16341
# 1   5be60449-818b-4179-9d32-bfe582537967-i0b0  ...             16341
# 2   46e0c1b3-0916-4974-8215-3245ae156d96-i0b0  ...             16341
# 3   3b549dad-b608-4d9d-bde8-c3ed93c9a425-i0b0  ...             18602
# 4   2d5c12db-8068-41c2-896b-fdb6a33d31b6-i0b0  ...             16341
# 5   c5f15622-59ad-4bba-8aab-1648eb7311c0-i0b0  ...             16341
# 6   65e024f9-d792-4c4e-8db0-3d5809b40f6e-i0b0  ...             18602
# 7   c76d0af3-d16a-45a8-885c-afe33da28e53-i0b0  ...             18602
# 8   30014635-0d81-42c0-8e4b-8724d6dbe02c-i0b0  ...             16341
# 9   a25cce9f-9994-47c7-84d9-4495e6443f99-i0b0  ...             18602
# 10  4cfbe55b-bb64-486a-9c8c-bb1add6ebdd8-i0b0  ...             16341
# 11  883c7cee-7aeb-4f96-932f-2544d1bf8350-i0b0  ...             16341
# 12  fea15e92-2aa5-4ae0-af91-eb10c7e2efd0-i0b0  ...             16341
# ...

# %%
# Vacinas utilizadas --------------------- Não usar -- Dados confusos (?????????Ministerio da saúde??????) ----------------------

dados.vacina_fabricante_nome.value_counts()
# Out:
# FUNDACAO BUTANTAN               1104500
# SERUM INSTITUTE OF INDIA LTD     352563
# FUNDACAO OSWALDO CRUZ            279708
# SINOVAC LIFE SCIENCE CO LTD       72268
# MINISTERIO DA SAUDE               26509
# BioNTech/Fosun Pharma/Pfizer        120
# Janssen-Cilag                        12
# Name: vacina_fabricante_nome, dtype: int64

# %%
## Heteroidentificação dos vacinados

dados.paciente_racaCor_valor.value_counts()
# Out:
# SEM INFORMACAO    563526
# PARDA             446964
# AMARELA           390988
# BRANCA            331328
# PRETA              61837
# INDIGENA           41037
# Name: paciente_racaCor_valor, dtype: int64

# %%
### 

dados.paciente_racaCor_valor.value_counts().plot(kind='bar')

# %%
## 30 cidades que mais vacinaram no estado de Pernambuco 

dados.estabelecimento_municipio_nome.value_counts().head(30)
# Out:
# RECIFE                     487895
# JABOATAO DOS GUARARAPES     92257
# CARUARU                     68690
# OLINDA                      57749
# PETROLINA                   51832
# CABO DE SANTO AGOSTINHO     36504
# PAULISTA                    36482
# GARANHUNS                   32061
# VITORIA DE SANTO ANTAO      24108
# CAMARAGIBE                  22661
# SERRA TALHADA               20619
# IGARASSU                    20385
# SALGUEIRO                   19717
# PESQUEIRA                   19502
# ARCOVERDE                   17007
# GOIANA                      15293
# LIMOEIRO                    15247
# ARARIPINA                   15045
# AGUAS BELAS                 15016
# SURUBIM                     13452
# OURICURI                    12994
# CARPINA                     12950
# GRAVATA                     12914
# ABREU E LIMA                11820
# BEZERROS                    11699
# BUIQUE                      11505
# BOM CONSELHO                11304
# ...

# %%
#Numero de vacinados por sexo biologico 

dados.paciente_enumSexoBiologico.value_counts()
# Out:
# F    1108002
# M     727678
# Name: paciente_enumSexoBiologico, dtype: int64

# %%
# Grafico dos vacinados por sexo 

dados.paciente_enumSexoBiologico.value_counts().plot(kind='pie')

# %%
dados.query()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-46eff810e567> in <module>()
# ----> 1 dados.query()
#
# TypeError: query() missing 1 required positional argument: 'expr'

# %%
dados.head()
# Out:
#                                  document_id  ... id_sistema_origem
# 0  ac8986a7-a04f-4aee-9a90-665879f85d2f-i0b0  ...             16341
# 1  5be60449-818b-4179-9d32-bfe582537967-i0b0  ...             16341
# 2  46e0c1b3-0916-4974-8215-3245ae156d96-i0b0  ...             16341
# 3  3b549dad-b608-4d9d-bde8-c3ed93c9a425-i0b0  ...             18602
# 4  2d5c12db-8068-41c2-896b-fdb6a33d31b6-i0b0  ...             16341
#
# [5 rows x 34 columns]
